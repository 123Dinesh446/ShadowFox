# %%
pi = 22/7
print(pi)
print(type(pi))
# Out:
# 3.142857142857143
# <class 'float'>

# %%
for_value = 4

# %%
P = 1000
R = 5
T = 3
SI = (P * R * T) / 100
print("Simple Interest:", SI)
# Out:
# Simple Interest: 150.0
