# %%
class Avenger:
    def __init__(self, name, age, gender, super_power, weapon, leader=False):
        self.name = name
        self.age = age
        self.gender = gender
        self.super_power = super_power
        self.weapon = weapon
        self.leader = leader
    def get_info(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Gender:", self.gender)
        print("Super Power:", self.super_power)
        print("Weapon:", self.weapon)
        print("-" * 30)
def is_leader(self):
        if self.leader:
            return f"{self.name} is a leader of the Avengers."
        else:
            return f"{self.name} is not a leader of the Avengers."

# %%
captain_america = Avenger(
    "Captain America", 101, "Male", "Super Strength", "Shield", True
)

iron_man = Avenger(
    "Iron Man", 48, "Male", "Technology", "Armor"
)

black_widow = Avenger(
    "Black Widow", 35, "Female", "Superhuman", "Batons"
)

hulk = Avenger(
    "Hulk", 49, "Male", "Unlimited Strength", "No Weapon"
)

thor = Avenger(
    "Thor", 1500, "Male", "Super Energy", "Mjölnir"
)

hawkeye = Avenger(
    "Hawkeye", 38, "Male", "Fighting Skills", "Bow and Arrows"
)

# %%
class Avenger:
    def __init__(self, name, age, gender, super_power, weapon, leader=False):
        self.name = name
        self.age = age
        self.gender = gender
        self.super_power = super_power
        self.weapon = weapon
        self.leader = leader
    def get_info(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Gender:", self.gender)
        print("Super Power:", self.super_power)
        print("Weapon:", self.weapon)
        print("-" * 30)
    def is_leader(self):
        if self.leader:
            return f"{self.name} is a leader of the Avengers."
        else:
            return f"{self.name} is not a leader of the Avengers."

captain_america = Avenger(
    "Captain America", 101, "Male", "Super Strength", "Shield", True
)

iron_man = Avenger(
    "Iron Man", 48, "Male", "Technology", "Armor"
)

black_widow = Avenger(
    "Black Widow", 35, "Female", "Superhuman", "Batons"
)

hulk = Avenger(
    "Hulk", 49, "Male", "Unlimited Strength", "No Weapon"
)

thor = Avenger(
    "Thor", 1500, "Male", "Super Energy", "Mjölnir"
)

hawkeye = Avenger(
    "Hawkeye", 38, "Male", "Fighting Skills", "Bow and Arrows"
)

avengers = [
    captain_america,
    iron_man,
    black_widow,
    hulk,
    thor,
    hawkeye
]

for hero in avengers:
    hero.get_info()
    print(hero.is_leader())
# Out:
# Name: Captain America
# Age: 101
# Gender: Male
# Super Power: Super Strength
# Weapon: Shield
# ------------------------------
# Captain America is a leader of the Avengers.
# Name: Iron Man
# Age: 48
# Gender: Male
# Super Power: Technology
# Weapon: Armor
# ------------------------------
# Iron Man is not a leader of the Avengers.
# Name: Black Widow
# Age: 35
# Gender: Female
# Super Power: Superhuman
# Weapon: Batons
# ------------------------------
# Black Widow is not a leader of the Avengers.
# Name: Hulk
# Age: 49
# Gender: Male
# Super Power: Unlimited Strength
# Weapon: No Weapon
# ------------------------------
# Hulk is not a leader of the Avengers.
# Name: Thor
# Age: 1500
# Gender: Male
# Super Power: Super Energy
# Weapon: Mjölnir
# ------------------------------
# Thor is not a leader of the Avengers.
# Name: Hawkeye
# Age: 38
# Gender: Male
# Super Power: Fighting Skills
# Weapon: Bow and Arrows
# ------------------------------
# ...
